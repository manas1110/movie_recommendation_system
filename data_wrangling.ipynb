# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns 
import ast

# %%
df=pd.read_csv("movies.csv")
print(df.columns)
df=df.drop(['Unnamed: 0'],axis=1)
df.head()
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'name', 'country', 'language', 'year',
#        'director', 'cast', 'rating', 'genre', 'rating_count', 'duration',
#        'description', 'image'],
#       dtype='object')
#    Unnamed: 0.1                      name        country  \
# 0             0  The Shawshank Redemption  United States
# 1             1             The Godfather  United States
# 2             2           The Dark Knight  United States
# 3             3     The Godfather Part II  United States
# 4             4              12 Angry Men  United States
#
#                  language  year              director  \
# 0                 English  1994        Frank Darabont
# 1                 English  1972  Francis Ford Coppola
# 2            Warner Bros.  2008     Christopher Nolan
# 3                 English  1974  Francis Ford Coppola
# 4  Orion-Nova Productions  1957          Sidney Lumet
#
#                                                 cast  rating  \
# ...

# %%
df['country'].unique()
df['language'].unique()
# Out:
# array(['English', 'Warner Bros.', 'Orion-Nova Productions',
#        'Official site: The Lord of the Rings Trilogy',
#        'Official Facebook', 'Italian', 'Official Site',
#        'Warner Bros. (United States)', 'Fantasy Films',
#        'Pacific Electric Building, Los Angeles, California, USA',
#        'French', 'Toho', 'Latin',
#        'Official site (3D re-release) (Germany)', 'Miyazaki collection',
#        'United Kingdom', 'Korean', 'Alfred J. Hitchcock Productions',
#        'Morocco', 'Columbia Pictures', 'Cantonese', 'Shinchosha Company',
#        'Durango and Silverton Narrow Gauge Railroad, Colorado, USA', nan,
#        'Hungary', 'Official site', 'German', 'Hindi',
#        'Paramount Pictures', 'Official Disney+ Hotstar',
#        'Metro-Goldwyn-Mayer Studios - 10202 W. Washington Blvd., Culver City, California, USA',
#        'Timberline Lodge, Mount Hood, Oregon, USA', 'HBOMAX',
#        'Official site (Russia)', 'Busan, South Korea',
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          250 non-null    object
#  1   country       234 non-null    object
#  2   language      233 non-null    object
#  3   year          250 non-null    int64
#  4   director      250 non-null    object
#  5   cast          250 non-null    object
#  6   rating        250 non-null    float64
#  7   genre         250 non-null    object
#  8   rating_count  250 non-null    int64
#  9   duration      250 non-null    object
#  10  description   250 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 21.6+ KB

# %% [markdown]
# DROP COLUMN LANGUAGE AS THIS DATA CONTAIN LOT OF IMPURITES THAT CANT BE HANDLE AND ALSO LANGUAGE IS SIMILAR TO COUNTRY, SO THESE BOTH CAN BE CONSIDERED AS SAME FEATURES

# %%
df_1=df.drop(['language'],axis=1)

# %%
df_1
# Out:
#      Unnamed: 0.1                      name        country  year  \
# 0               0  The Shawshank Redemption  United States  1994
# 1               1             The Godfather  United States  1972
# 2               2           The Dark Knight  United States  2008
# 3               3     The Godfather Part II  United States  1974
# 4               4              12 Angry Men  United States  1957
# ..            ...                       ...            ...   ...
# 245           245            Cool Hand Luke  United States  1967
# 246           246     It Happened One Night  United States  1934
# 247           247        Gangs of Wasseypur          India  2012
# 248           248                  Drishyam          India  2015
# 249           249              Paris, Texas   West Germany  1984
#
#                  director                                               cast  \
# 0          Frank Darabont    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  250 non-null    int64
#  1   name          250 non-null    object
#  2   country       234 non-null    object
#  3   year          250 non-null    int64
#  4   director      250 non-null    object
#  5   cast          250 non-null    object
#  6   rating        250 non-null    float64
#  7   genre         250 non-null    object
#  8   rating_count  250 non-null    int64
#  9   duration      250 non-null    object
#  10  description   250 non-null    object
#  11  image         250 non-null    object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 23.6+ KB

# %%
df_1.head(5)
# Out:
#    Unnamed: 0.1                      name        country  year  \
# 0             0  The Shawshank Redemption  United States  1994
# 1             1             The Godfather  United States  1972
# 2             2           The Dark Knight  United States  2008
# 3             3     The Godfather Part II  United States  1974
# 4             4              12 Angry Men  United States  1957
#
#                director                                               cast  \
# 0        Frank Darabont    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1  Francis Ford Coppola             ['Mario Puzo', 'Francis Ford Coppola']
# 2     Christopher Nolan  ['Jonathan Nolan', 'Christopher Nolan', 'David...
# 3  Francis Ford Coppola             ['Francis Ford Coppola', 'Mario Puzo']
# 4          Sidney Lumet                                  ['Reginald Rose']
#
#    rating                 genre  rating_count duration  \
# 0     9.3                 Drama       2949951    2H22M
# ...

# %% [markdown]
# CONVERTING THE DURATION COLUMN INTO MINUTES

# %%
def func(x):
    if ('H' in x) and ('M' in  x):
        a=int(x.split('H')[0])*60
        b=x.split('H')[1].split('M')[0].strip()
        if b=='':
            b=0
        else:
            b=int(x.split('H')[1].split('M')[0])
        return (a+b)
    elif 'H' in x:
        a=int(x.split('H')[0])*60
        return a
    else:
        b=int(x.split('M')[0])
        return b

df_1['duration']=df_1['duration'].apply(func)

# %%
df_1.head()
# Out:
#    Unnamed: 0.1                      name        country  year  \
# 0             0  The Shawshank Redemption  United States  1994
# 1             1             The Godfather  United States  1972
# 2             2           The Dark Knight  United States  2008
# 3             3     The Godfather Part II  United States  1974
# 4             4              12 Angry Men  United States  1957
#
#                director                                               cast  \
# 0        Frank Darabont    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1  Francis Ford Coppola             ['Mario Puzo', 'Francis Ford Coppola']
# 2     Christopher Nolan  ['Jonathan Nolan', 'Christopher Nolan', 'David...
# 3  Francis Ford Coppola             ['Francis Ford Coppola', 'Mario Puzo']
# 4          Sidney Lumet                                  ['Reginald Rose']
#
#    rating                 genre  rating_count  duration  \
# 0     9.3                 Drama       2949951       142
# ...

# %%
#df_1['cast'] = df_1['cast'].apply(lambda x: ', '.join(x))

# %% [markdown]
# NOW IMPROVINF CAST COLUMN CONVERTING IT TO CSV VALUES AND DOING SAME WITH GENRE COLUMN

# %%
# Convert the string representation of lists to actual lists
df_1['cast'] = df_1['cast'].apply(ast.literal_eval)

# Convert the cast lists to CSV format
df_1['cast'] = df_1['cast'].apply(lambda x: ', '.join(x))

# %%
df_1.head(5)
# Out:
#    Unnamed: 0.1                      name        country  year  \
# 0             0  The Shawshank Redemption  United States  1994
# 1             1             The Godfather  United States  1972
# 2             2           The Dark Knight  United States  2008
# 3             3     The Godfather Part II  United States  1974
# 4             4              12 Angry Men  United States  1957
#
#                director                                               cast  \
# 0        Frank Darabont            Tim Robbins, Morgan Freeman, Bob Gunton
# 1  Francis Ford Coppola                   Mario Puzo, Francis Ford Coppola
# 2     Christopher Nolan  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3  Francis Ford Coppola                   Francis Ford Coppola, Mario Puzo
# 4          Sidney Lumet                                      Reginald Rose
#
#    rating                 genre  rating_count  duration  \
# 0     9.3                 Drama       2949951       142
# ...

# %%
df_1['genre'].unique()[:5]
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History'],
#       dtype=object)

# %%
df_1['genre'] = df_1['genre'].apply(lambda x: x.split(', '))

# %%
df_1['genre'] = df_1['genre'].apply(lambda x: ', '.join(x))

# %%
df_1.head()
# Out:
#    Unnamed: 0.1                      name        country  year  \
# 0             0  The Shawshank Redemption  United States  1994
# 1             1             The Godfather  United States  1972
# 2             2           The Dark Knight  United States  2008
# 3             3     The Godfather Part II  United States  1974
# 4             4              12 Angry Men  United States  1957
#
#                director                                               cast  \
# 0        Frank Darabont            Tim Robbins, Morgan Freeman, Bob Gunton
# 1  Francis Ford Coppola                   Mario Puzo, Francis Ford Coppola
# 2     Christopher Nolan  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3  Francis Ford Coppola                   Francis Ford Coppola, Mario Puzo
# 4          Sidney Lumet                                      Reginald Rose
#
#    rating                 genre  rating_count  duration  \
# 0     9.3                 Drama       2949951       142
# ...

# %%
df_1.to_csv('IMDBcleaned.csv', index=False)
