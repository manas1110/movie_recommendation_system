# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('IMDBcleaned.csv')

# %%
df.head(5)
# Out:
#                        name        country  year              director  \
# 0  The Shawshank Redemption  United States  1994        Frank Darabont
# 1             The Godfather  United States  1972  Francis Ford Coppola
# 2           The Dark Knight  United States  2008     Christopher Nolan
# 3     The Godfather Part II  United States  1974  Francis Ford Coppola
# 4              12 Angry Men  United States  1957          Sidney Lumet
#
#                                                 cast  rating  \
# 0            Tim Robbins, Morgan Freeman, Bob Gunton     9.3
# 1                   Mario Puzo, Francis Ford Coppola     9.2
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer     9.0
# 3                   Francis Ford Coppola, Mario Puzo     9.0
# 4                                      Reginald Rose     9.0
#
#                   genre  rating_count  duration  \
# 0                 Drama       2949951       142
# 1          Crime, Drama       2056341       175
# 2  Action, Crime, Drama       2925228       152
# 3          Crime, Drama       1389782       202
# 4          Crime, Drama        887543        96
#
#                                          description
# 0  A banker convicted of uxoricide forms a friend...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
# 3  The early life and career of Vito Corleone in ...
# 4  The jury in a New York City murder trial is fr...

# %%
print ('Rows     : ', df.shape[0])
print ('Columns  : ', df.shape[1])
print ('\nFeatures : ', df.columns.tolist())
print ('\nMissing values :  ', df.isnull().sum().values.sum())
print ('\nUnique values :  \n', df.nunique())
# Out:
# Rows     :  250
# Columns  :  10
#
# Features :  ['name', 'country', 'year', 'director', 'cast', 'rating', 'genre', 'rating_count', 'duration', 'description']
#
# Missing values :   0
#
# Unique values :
#  name            250
# country          23
# year             87
# director        154
# cast            241
# rating           13
# genre           103
# rating_count    250
# duration        101
# description     250
# dtype: int64

# %%
df.describe().T
# Out:
#               count         mean            std      min        25%       50%  \
# year          250.0    1987.6800      25.562303   1921.0    1968.75    1995.0
# rating        250.0       8.3092       0.233438      8.0       8.10       8.2
# rating_count  250.0  709461.3880  571781.902456  44440.0  234959.50  576301.5
# duration      250.0     130.8560      32.186007     45.0     109.25     128.0
#
#                     75%        max
# year             2008.0     2024.0
# rating              8.4        9.3
# rating_count  1043863.5  2949951.0
# duration          147.0      321.0

# %%
df = df[['name','director','cast','description','genre']]
df.index = list(range(1,251))
df.head(5)
# Out:
#                        name              director  \
# 1  The Shawshank Redemption        Frank Darabont
# 2             The Godfather  Francis Ford Coppola
# 3           The Dark Knight     Christopher Nolan
# 4     The Godfather Part II  Francis Ford Coppola
# 5              12 Angry Men          Sidney Lumet
#
#                                                 cast  \
# 1            Tim Robbins, Morgan Freeman, Bob Gunton
# 2                   Mario Puzo, Francis Ford Coppola
# 3  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 4                   Francis Ford Coppola, Mario Puzo
# 5                                      Reginald Rose
#
#                                          description                 genre
# 1  A banker convicted of uxoricide forms a friend...                 Drama
# 2  The aging patriarch of an organized crime dyna...          Crime, Drama
# 3  When a menace known as the Joker wreaks havoc ...  Action, Crime, Drama
# 4  The early life and career of Vito Corleone in ...          Crime, Drama
# 5  The jury in a New York City murder trial is fr...          Crime, Drama

# %%
df.to_csv('IMDBfeatures.csv', index=False)
